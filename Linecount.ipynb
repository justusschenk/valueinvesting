# %%
import nbformat

# Load the current notebook file
sharpe = "Sharpe-ratio.ipynb"  # Replace with your actual notebook name
with open(sharpe, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Count lines in code cells
code_lines_sharpe = sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (Sharpe-ratio): {code_lines_sharpe}")

# Load the current notebook file
regression = "Regression.ipynb"  # Replace with your actual notebook name
with open(regression, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Count lines in code cells
code_lines_regression = sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (Regression): {code_lines_regression}")

# Load the current notebook file
ffc = "Fama-French-Carhart.ipynb"  # Replace with your actual notebook name
with open(ffc, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Count lines in code cells
code_lines_ffc = sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (FFC): {code_lines_ffc}")

# Load the current notebook file
pc = "Portfolio-composition.ipynb"  # Replace with your actual notebook name
with open(pc, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Count lines in code cells
code_lines_pc = sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (Portfolio Comp.): {code_lines_pc}")

# Load the current notebook file
analytics = "Analytics.ipynb"  # Replace with your actual notebook name
with open(analytics, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Count lines in code cells
code_lines_an = sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (Analytics): {code_lines_an}")

# Load the current notebook file
mst = "Market Structure Transformation.ipynb"  # Replace with your actual notebook name
with open(mst, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Count lines in code cells
code_lines_mst = sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (MST): {code_lines_mst}")

# Load the current notebook file
cra = "Changing Risk Aversion.ipynb"  # Replace with your actual notebook name
with open(cra, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Count lines in code cells
code_lines_cra = sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (CRA): {code_lines_cra}")

# Load the current notebook file
br = "Behavioral Regimes.ipynb"  # Replace with your actual notebook name
with open(br, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Count lines in code cells
code_lines_br = sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (Behavioral Regimes): {code_lines_br}")

# Load the current notebook file
risk = "Risk.ipynb"  # Replace with your actual notebook name
with open(risk, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Count lines in code cells
code_lines_risk = sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (Risk): {code_lines_risk}")

# Load the current notebook file
aod = "Analysis of Decline.ipynb"  # Replace with your actual notebook name
with open(aod, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Load the current notebook file
csr = "Cross-Sectional-Regressions.ipynb"  # Replace with your actual notebook name
with open(csr, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)

# Count lines in code cells
code_lines_aod = sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (Analysis of Decline): {code_lines_aod}")

# Count lines in code cells
code_lines_csr= sum(len(cell['source'].splitlines()) for cell in nb.cells if cell['cell_type'] == 'code')
print(f"Total number of code lines (CSR): {code_lines_csr}")

print("================================================")

total_lines = code_lines_sharpe + code_lines_regression + code_lines_ffc + code_lines_pc + code_lines_an + code_lines_mst + code_lines_cra + code_lines_risk + code_lines_aod +code_lines_csr

print("Total numbers of code lines: ", total_lines)
# Out:
# Total number of code lines (Sharpe-ratio): 62
# Total number of code lines (Regression): 1633
# Total number of code lines (FFC): 1816
# Total number of code lines (Portfolio Comp.): 1968
# Total number of code lines (Analytics): 206
# Total number of code lines (MST): 1075
# Total number of code lines (CRA): 52
# Total number of code lines (Behavioral Regimes): 39
# Total number of code lines (Risk): 46
# Total number of code lines (Analysis of Decline): 1103
# Total number of code lines (CSR): 1103
# ...
# Total numbers of code lines:  9064
